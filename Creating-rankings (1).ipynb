# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
# Reading in stats.csv, calculating each relevant stat's correlation with margin
# Margin is positive for a winning team, negative for a losing team
stats = pd.read_csv("stats.csv")
stats = stats.rename(columns = {"ContendedPossessions": "ContestedPossessions"})
stats = stats.rename(columns = {"UncontendedPossessions": "UncontestedPossessions"})

# %%
# Dropping non-in-game stats
corr = stats.drop(["Score", "Height", "Weight", "BrownlowVotes", "Season"], axis = 1).corr()

plt.figure(figsize = (12,9))
sn.heatmap(corr, cmap = "Blues")
plt.title("Stat correlations")
plt.show()

# %%
# Of particular interest are the correlations between various stats and ultimate game margin

# Drop disposals because it is entirely comprised of the two more in depth stats—uncontested possesions and contested
# possessions
margin_corr = corr["Margin"].sort_values(ascending = False).drop("Margin").drop("Disposals")
margin_corr
# Out:
# GoalAssists               0.171273
# Goals                     0.165482
# Marks                     0.140960
# Kicks                     0.137726
# Inside50s                 0.137442
# UncontestedPossessions    0.128609
# MarksInside50             0.124467
# Behinds                   0.076345
# ContestedPossessions      0.065979
# Handballs                 0.065791
# ContestedMarks            0.053661
# Bounces                   0.052801
# Clearances                0.030578
# FreesFor                  0.022983
# Tackles                   0.019528
# OnePercenters             0.006530
# Hitouts                   0.005791
# PercentPlayed            -0.000122
# FreesAgainst             -0.023000
# Rebound50s               -0.044184
# Clangers                 -0.049729
# Name: Margin, dtype: float64

# %%
# As could probably be predicted, stats related with scoring, such as goals and goal assists are the most
# correlated with margin, while negative stats like clangers and frees against are negatively correlated with margin

# %%
# We can now use these correlations to provide a weighting for each stat, to calculate an overall score
# for a player's match
ratings = []
for i in stats.index:
    rating = 0
    for stat in margin_corr.index:
        rating += stats.loc[i, stat] * margin_corr[stat]
    ratings.append(rating)

stats["Ratings"] = ratings
stats
# Out:
#                          Team                Player     D.O.B  Height  Weight  \
# 0                     Geelong  Dangerfield, Patrick    5/4/90     189      92
# 1      Greater Western Sydney           Kelly, Josh   12/2/95     184      82
# 2                 Collingwood            Swan, Dane   25/2/84     185      93
# 3                    Essendon      Zaharakis, David   21/2/90     180      79
# 4                  Gold Coast          Sexton, Alex   3/12/93     186      84
# ...                       ...                   ...       ...     ...     ...
# 63707                Richmond          Conca, Reece   12/8/92     181      83
# 63708                St Kilda    Dennis-Lane, Trent   30/8/88     182      75
# 63709                Adelaide       Petrenko, Jared  22/12/89     178      81
# 63710                 Carlton       McInnes, Andrew   20/3/92     191      87
# 63711         North Melbourne        Harper, Kieran   15/6/92     187      84
#
#                 Position  Season Round     Date  Score  ...  BrownlowVotes  \
# 0      Midfield, Forward    2016   R23  27/8/16  155.0  ...              3
# 1               Midfield    2018   R20   5/8/18  151.0  ...              3
# 2               Midfield    2015    R3  17/4/15  140.0  ...              3
# 3               Midfield    2017   R22  19/8/17   90.0  ...              3
# 4                Forward    2016   R18  23/7/16  105.0  ...              0
# ...                  ...     ...   ...      ...    ...  ...            ...
# 63707           Midfield    2013    EF   8/9/13   96.0  ...              0
# 63708            Forward    2013    R1  30/3/13   77.0  ...              0
# 63709            Forward    2012    R4  21/4/12   96.0  ...              0
# 63710           Defender    2012   R22  25/8/12   86.0  ...              0
# 63711            Forward    2012   R15   7/7/12   84.0  ...              0
#
#       ContestedPossessions UncontestedPossessions ContestedMarks  \
# 0                       17                     16              0
# 1                       22                     21              0
# 2                       17                     22              0
# 3                       10                     28              0
# 4                        7                     17              0
# ...                    ...                    ...            ...
# 63707                    0                      0              0
# 63708                    0                      0              0
# 63709                    0                      0              0
# 63710                    0                      0              0
# 63711                    0                      0              0
#
#        MarksInside50  OnePercenters  Bounces  GoalAssists  PercentPlayed  \
# 0                  0              0        1            6             85
# 1                  1              2        2            4             95
# 2                  1              4        0            3             87
# 3                  0              2        0            3             89
# 4                  1              0        0            3             90
# ...              ...            ...      ...          ...            ...
# 63707              0              0        0            0              8
# 63708              0              0        0            0             25
# 63709              0              0        0            0              1
# 63710              0              0        0            0              1
# 63711              0              0        0            0             16
#
#          Ratings
# 0      10.804963
# 1      13.468338
# 2      12.010178
# 3      11.636039
# 4       9.370521
# ...          ...
# 63707  -0.000975
# 63708  -0.003046
# 63709  -0.000122
# 63710  -0.000122
# 63711  -0.001949
#
# [63712 rows x 38 columns]

# %%
stats.to_csv("stats_with_ratings.csv", index = False)
